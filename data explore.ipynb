# %%
import pandas as pd

# %%
raw_data = pd.read_csv("./data/news_data_with_y1030_sentiment.csv")

# %%
raw_data.columns
# Out:
# Index(['Unnamed: 0', 'Item_URL', 'Item_Author', 'Item_PostDate', 'Item_Title',
#        'Item_Views', 'Item_Likes', 'Item_Comments', 'news_author_x',
#        'news_text', 'Item_Time', 'Item_Date', 'title', 'sentence_length',
#        'word_length', 'word_!', 'word_:', 'word_?', 'news_source',
#        'news_author_y', 'top1p_views', 'top5p_views', 'top10p_views',
#        'top15p_views', 'top20p_views', 'top25p_views', 'top30p_views',
#        'top1p_likes', 'top5p_likes', 'top10p_likes', 'top15p_likes',
#        'top20p_likes', 'top25p_likes', 'top30p_likes', 'top1p_comments',
#        'top5p_comments', 'top10p_comments', 'top15p_comments',
#        'top20p_comments', 'top25p_comments', 'top30p_comments', 'Company_ID',
#        'sentiment', 'score'],
#       dtype='object')

# %%
# select features

data = raw_data[['Item_Author', 'Company_ID', 'Item_Title', 'title', 'news_text', 'sentence_length', 'word_length', 'word_!', 'word_:', 'word_?', 'sentiment', 'score', 
        'Item_Views', 'Item_Likes', 'Item_Comments', 
        'top1p_views', 'top5p_views', 'top10p_views', 'top15p_views', 'top20p_views', 'top25p_views', 'top30p_views',
        'top1p_likes', 'top5p_likes', 'top10p_likes', 'top15p_likes', 'top20p_likes', 'top25p_likes', 'top30p_likes', 
        'top1p_comments', 'top5p_comments', 'top10p_comments', 'top15p_comments', 'top20p_comments', 'top25p_comments', 'top30p_comments']]

# %%
data.columns
# Out:
# Index(['Item_Author', 'Company_ID', 'Item_Title', 'title', 'news_text',
#        'sentence_length', 'word_length', 'word_!', 'word_:', 'word_?',
#        'sentiment', 'score', 'Item_Views', 'Item_Likes', 'Item_Comments',
#        'top1p_views', 'top5p_views', 'top10p_views', 'top15p_views',
#        'top20p_views', 'top25p_views', 'top30p_views', 'top1p_likes',
#        'top5p_likes', 'top10p_likes', 'top15p_likes', 'top20p_likes',
#        'top25p_likes', 'top30p_likes', 'top1p_comments', 'top5p_comments',
#        'top10p_comments', 'top15p_comments', 'top20p_comments',
#        'top25p_comments', 'top30p_comments'],
#       dtype='object')

# %%
data['Item_Author']
# Out:
# 0         平安银行资讯
# 1         平安银行资讯
# 2         平安银行资讯
# 3         平安银行资讯
# 4         平安银行资讯
#            ...
# 986013    中寰股份资讯
# 986014    中寰股份资讯
# 986015    中寰股份资讯
# 986016    中寰股份资讯
# 986017    中寰股份资讯
# Name: Item_Author, Length: 986018, dtype: object

# %%
cat_cols = ['Item_Author', 'Company_ID', 'sentiment']
cont_cols = ['word_length', 'word_!', 'word_:', 'word_?', 'score']
# tar_cols = ['Item_Views', 'Item_Likes', 'Item_Comments']

# %%
data[cat_cols] = data[cat_cols].apply(lambda c: c.astype('category'))
# Out:
# C:\Users\ZIQING002\AppData\Local\Temp\ipykernel_31752\3328079898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[cat_cols] = data[cat_cols].apply(lambda c: c.astype('category'))

# %%
data.dtypes
# Out:
# Item_Author        category
# Company_ID         category
# Item_Title           object
# title                object
# news_text            object
# sentence_length       int64
# word_length           int64
# word_!                int64
# word_:                int64
# word_?                int64
# sentiment          category
# score               float64
# Item_Views          float64
# Item_Likes          float64
# Item_Comments       float64
# top1p_views           int64
# top5p_views           int64
# top10p_views          int64
# top15p_views          int64
# top20p_views          int64
# top25p_views          int64
# top30p_views          int64
# top1p_likes           int64
# top5p_likes           int64
# top10p_likes          int64
# top15p_likes          int64
# top20p_likes          int64
# top25p_likes          int64
# top30p_likes          int64
# top1p_comments        int64
# top5p_comments        int64
# top10p_comments       int64
# top15p_comments       int64
# top20p_comments       int64
# top25p_comments       int64
# top30p_comments       int64
# dtype: object

# %%
raw_data.describe(include='all')
# Out:
#          Unnamed: 0                                           Item_URL
# count   986018.0000                                             986018  \
# unique          NaN                                             985752
# top             NaN  https://guba.eastmoney.com/news,601777,1111695...
# freq            NaN                                                  2
# mean    493008.5000                                                NaN
# std     284639.0232                                                NaN
# min          0.0000                                                NaN
# 25%     246504.2500                                                NaN
# 50%     493008.5000                                                NaN
# 75%     739512.7500                                                NaN
# max     986017.0000                                                NaN
#
#        Item_Author        Item_PostDate                            Item_Title
# count       986018               986018                                986018  \
# unique        4749               408094                                985752
# top         宁德时代资讯  2022-03-12 07:41:28  力帆科技：融资净偿还860.29万元，融资余额3.29亿元（11-25）
# freq           875                   22                                     2
# mean           NaN                  NaN                                   NaN
# std            NaN                  NaN                                   NaN
# min            NaN                  NaN                                   NaN
# 25%            NaN                  NaN                                   NaN
# 50%            NaN                  NaN                                   NaN
# 75%            NaN                  NaN                                   NaN
# max            NaN                  NaN                                   NaN
#
#            Item_Views     Item_Likes  Item_Comments news_author_x
# count   986018.000000  986018.000000  986018.000000        986018  \
# unique            NaN            NaN            NaN          1404
# top               NaN            NaN            NaN           财智星
# freq              NaN            NaN            NaN        955586
# mean       538.720718       1.361425       2.295520           NaN
# std       1116.258689      10.829394      19.975907           NaN
# min         59.000000       0.000000       0.000000           NaN
# 25%        276.000000       0.000000       0.000000           NaN
# 50%        353.000000       0.000000       0.000000           NaN
# 75%        507.000000       1.000000       1.000000           NaN
# max     163000.000000    1998.000000    4756.000000           NaN
#
#                                                 news_text  ... top1p_comments
# count                                              986018  ...  986018.000000  \
# unique                                             985750  ...            NaN
# top      来源：东方财富Choice数据 作者：财智星 力帆科技融资融券信息显示，2021年12月2...  ...            NaN
# freq                                                    2  ...            NaN
# mean                                                  NaN  ...       0.010428
# std                                                   NaN  ...       0.101583
# min                                                   NaN  ...       0.000000
# 25%                                                   NaN  ...       0.000000
# 50%                                                   NaN  ...       0.000000
# 75%                                                   NaN  ...       0.000000
# max                                                   NaN  ...       1.000000
#
#        top5p_comments top10p_comments  top15p_comments  top20p_comments
# count   986018.000000   986018.000000    986018.000000    986018.000000  \
# unique            NaN             NaN              NaN              NaN
# top               NaN             NaN              NaN              NaN
# freq              NaN             NaN              NaN              NaN
# mean         0.054521        0.119516         0.194710         0.281378
# std          0.227044        0.324395         0.395978         0.449672
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        0.000000         0.000000         1.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#         top25p_comments  top30p_comments     Company_ID sentiment
# count     986018.000000    986018.000000  986018.000000    986018  \
# unique              NaN              NaN            NaN         3
# top                 NaN              NaN            NaN   neutral
# freq                NaN              NaN            NaN    520575
# mean           0.378147         0.701338  353945.481784       NaN
# std            0.484925         0.457671  274159.907037       NaN
# min            0.000000         0.000000       1.000000       NaN
# 25%            0.000000         0.000000    2539.000000       NaN
# 50%            0.000000         1.000000  301010.000000       NaN
# 75%            1.000000         1.000000  601288.000000       NaN
# max            1.000000         1.000000  873223.000000       NaN
#
#                 score
# count   986018.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.045141
# std          0.684751
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
#
# [11 rows x 44 columns]

# %%
data.to_csv("./data/processed_data.csv")
