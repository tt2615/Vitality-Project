# %%
import pandas as pd
import pyreadr

# %%
data = pyreadr.read_r('./data/data.RData')
# print(data.keys())
data = data["eastmoney_to_ntu"]

# %%
data.columns
# Out:
# Index(['stock_code', 'item_title', 'article_postdate', 'item_author',
#        'article_author', 'article_source', 'article_content', 'item_views',
#        'item_comment_counts', 'article_likes', 'date', 'year', 'month',
#        'eastmoney_robo_journalism', 'media_robo_journalism',
#        'SMA_robo_journalism', 'viral'],
#       dtype='object')

# %%
data = data[['item_title', 'stock_code', 'item_author', 'article_author', 'article_source', 'eastmoney_robo_journalism', 'media_robo_journalism', 'SMA_robo_journalism', 'year', 'month','viral']]

# %%
cat_cols = ['stock_code', 'item_author', 'article_author', 'article_source', 'eastmoney_robo_journalism', 'media_robo_journalism', 'SMA_robo_journalism', 'year', 'month','viral']
data[cat_cols] = data[cat_cols].apply(lambda c: c.astype('category'))

# %%
data.describe(include='all')
# Out:
#         item_title stock_code item_author article_author article_source
# count      6603696    6603696     6603696        6603262        6603696  \
# unique     6405069       5052        5159           5799           2045
# top     百联股份今日热门盘点     600519        股市胖虎                  东方财富Choice数据
# freq           116      10411      426876        3252893        4179997
#
#         eastmoney_robo_journalism  media_robo_journalism  SMA_robo_journalism
# count                   6603696.0              6603696.0            6603696.0  \
# unique                        2.0                    2.0                  2.0
# top                           1.0                    0.0                  0.0
# freq                    3634888.0              5709855.0            4878621.0
#
#              year      month      viral
# count   6603696.0  6603696.0  6603696.0
# unique        7.0       12.0        2.0
# top        2022.0       12.0        0.0
# freq    1987630.0   680738.0  6288140.0

# %%
data.to_csv('./data/p_data_wo_content.csv')

# %%
import pandas as pd

# %%
data1 = pd.read_csv('./data/eastmoney_data_senti.csv')
# Out:
# /var/folders/52/5ygfc9d94sscvjzdx8yvt2sm0000gq/T/ipykernel_82384/3929029688.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./data/eastmoney_data_senti.csv')

# %%
data1.describe(include='all')
# Out:
#         item_title item_author article_author article_source    item_views
# count      6603696     6603696        6603696        6603696  6.603696e+06  \
# unique     6405069        5159           5800           2045           NaN
# top     百联股份今日热门盘点        股市胖虎            财智星   东方财富Choice数据           NaN
# freq           116      426876        3039821        4179997           NaN
# mean           NaN         NaN            NaN            NaN  1.765761e+03
# std            NaN         NaN            NaN            NaN  3.372575e+04
# min            NaN         NaN            NaN            NaN  2.700000e+01
# 25%            NaN         NaN            NaN            NaN  3.410000e+02
# 50%            NaN         NaN            NaN            NaN  5.070000e+02
# 75%            NaN         NaN            NaN            NaN  8.310000e+02
# max            NaN         NaN            NaN            NaN  7.625000e+07
#
#         item_comment_counts  article_likes          year         month
# count          6.603696e+06   6.603696e+06  6.603696e+06  6.603696e+06  \
# unique                  NaN            NaN           NaN           NaN
# top                     NaN            NaN           NaN           NaN
# freq                    NaN            NaN           NaN           NaN
# mean           3.481803e+00   2.901667e+00  2.021472e+03  6.593989e+00
# std            2.461240e+01   1.583375e+01  1.164505e+00  3.552674e+00
# min            0.000000e+00   0.000000e+00  2.017000e+03  1.000000e+00
# 25%            0.000000e+00   0.000000e+00  2.021000e+03  4.000000e+00
# 50%            0.000000e+00   1.000000e+00  2.022000e+03  7.000000e+00
# 75%            1.000000e+00   3.000000e+00  2.022000e+03  1.000000e+01
# max            1.100000e+04   3.250000e+03  2.023000e+03  1.200000e+01
#
#         eastmoney_robo_journalism  media_robo_journalism  SMA_robo_journalism
# count                6.603696e+06           6.603696e+06         6.603696e+06  \
# unique                        NaN                    NaN                  NaN
# top                           NaN                    NaN                  NaN
# freq                          NaN                    NaN                  NaN
# mean                 5.504324e-01           1.353547e-01         2.612287e-01
# std                  4.974501e-01           3.421020e-01         4.393043e-01
# min                  0.000000e+00           0.000000e+00         0.000000e+00
# 25%                  0.000000e+00           0.000000e+00         0.000000e+00
# 50%                  1.000000e+00           0.000000e+00         0.000000e+00
# 75%                  1.000000e+00           0.000000e+00         1.000000e+00
# max                  1.000000e+00           1.000000e+00         1.000000e+00
#
#                viral article_source_cate item_author_cate  sentiment_score
# count   6.603696e+06             6603696          6603696     6.603696e+06
# unique           NaN                 219             5158              NaN
# top              NaN                东方财富             股市胖虎              NaN
# freq             NaN             4181680           426876              NaN
# mean    4.778476e-02                 NaN              NaN     8.064672e-02
# std     2.133105e-01                 NaN              NaN     1.316210e-01
# min     0.000000e+00                 NaN              NaN    -8.461144e-01
# 25%     0.000000e+00                 NaN              NaN     4.519547e-03
# 50%     0.000000e+00                 NaN              NaN     8.821894e-02
# 75%     0.000000e+00                 NaN              NaN     1.616404e-01
# max     1.000000e+00                 NaN              NaN     9.834914e-01

# %%
data2 = pd.read_csv('./data/eastmoney_topic.csv')
# Out:
# /var/folders/52/5ygfc9d94sscvjzdx8yvt2sm0000gq/T/ipykernel_84209/2502695927.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv('./data/eastmoney_topic.csv')

# %%
data2.describe(include='all')
# Out:
#         item_title item_author article_author article_source    item_views
# count      6603696     6603696        6603696        6603696  6.603696e+06  \
# unique     6405069        5159           5800           2045           NaN
# top     百联股份今日热门盘点        股市胖虎            财智星   东方财富Choice数据           NaN
# freq           116      426876        3039821        4179997           NaN
# mean           NaN         NaN            NaN            NaN  1.765761e+03
# std            NaN         NaN            NaN            NaN  3.372575e+04
# min            NaN         NaN            NaN            NaN  2.700000e+01
# 25%            NaN         NaN            NaN            NaN  3.410000e+02
# 50%            NaN         NaN            NaN            NaN  5.070000e+02
# 75%            NaN         NaN            NaN            NaN  8.310000e+02
# max            NaN         NaN            NaN            NaN  7.625000e+07
#
#         item_comment_counts  article_likes          year         month
# count          6.603696e+06   6.603696e+06  6.603696e+06  6.603696e+06  \
# unique                  NaN            NaN           NaN           NaN
# top                     NaN            NaN           NaN           NaN
# freq                    NaN            NaN           NaN           NaN
# mean           3.481803e+00   2.901667e+00  2.021472e+03  6.593989e+00
# std            2.461240e+01   1.583375e+01  1.164505e+00  3.552674e+00
# min            0.000000e+00   0.000000e+00  2.017000e+03  1.000000e+00
# 25%            0.000000e+00   0.000000e+00  2.021000e+03  4.000000e+00
# 50%            0.000000e+00   1.000000e+00  2.022000e+03  7.000000e+00
# 75%            1.000000e+00   3.000000e+00  2.022000e+03  1.000000e+01
# max            1.100000e+04   3.250000e+03  2.023000e+03  1.200000e+01
#
#         eastmoney_robo_journalism  media_robo_journalism  SMA_robo_journalism
# count                6.603696e+06           6.603696e+06         6.603696e+06  \
# unique                        NaN                    NaN                  NaN
# top                           NaN                    NaN                  NaN
# freq                          NaN                    NaN                  NaN
# mean                 5.504324e-01           1.353547e-01         2.612287e-01
# std                  4.974501e-01           3.421020e-01         4.393043e-01
# min                  0.000000e+00           0.000000e+00         0.000000e+00
# 25%                  0.000000e+00           0.000000e+00         0.000000e+00
# 50%                  1.000000e+00           0.000000e+00         0.000000e+00
# 75%                  1.000000e+00           0.000000e+00         1.000000e+00
# max                  1.000000e+00           1.000000e+00         1.000000e+00
#
#                viral article_source_cate item_author_cate  sentiment_score
# count   6.603696e+06             6603696          6603696     6.603696e+06  \
# unique           NaN                 219             5158              NaN
# top              NaN                东方财富             股市胖虎              NaN
# freq             NaN             4181680           426876              NaN
# mean    4.778476e-02                 NaN              NaN     8.064672e-02
# std     2.133105e-01                 NaN              NaN     1.316210e-01
# min     0.000000e+00                 NaN              NaN    -8.461144e-01
# 25%     0.000000e+00                 NaN              NaN     4.519547e-03
# 50%     0.000000e+00                 NaN              NaN     8.821894e-02
# 75%     0.000000e+00                 NaN              NaN     1.616404e-01
# max     1.000000e+00                 NaN              NaN     9.834914e-01
#
#                             cut_titles
# count                          6603696  \
# unique                         6399519
# top     ['百联', '股份', '今日', '热门', '盘点']
# freq                               116
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#                                                    topics  dominant_topic
# count                                             6603696    6.603696e+06
# unique                                            6549595             NaN
# top     [(0, 0.020837696), (1, 0.020837696), (2, 0.854...             NaN
# freq                                                   82             NaN
# mean                                                  NaN    4.003182e+00
# std                                                   NaN    2.141182e+00
# min                                                   NaN    0.000000e+00
# 25%                                                   NaN    3.000000e+00
# 50%                                                   NaN    5.000000e+00
# 75%                                                   NaN    6.000000e+00
# max                                                   NaN    7.000000e+00

# %%
data2['topics'][0]
# Out:
# '[(0, 0.013899067), (1, 0.013960035), (2, 0.12508488), (3, 0.013899348), (4, 0.6523453), (5, 0.013910475), (6, 0.013899067), (7, 0.1530018)]'

# %%
data2['dominant_topic']
# Out:
# 0          4
# 1          4
# 2          0
# 3          1
# 4          0
#           ..
# 6603691    4
# 6603692    4
# 6603693    4
# 6603694    4
# 6603695    3
# Name: dominant_topic, Length: 6603696, dtype: int64

# %%
data2['topics_val'] = data2['topics'].apply(lambda x: [float(tup.split(',')[1][1:-1]) for tup in x.strip('[]').split('),')])

# %%
data3 = pd.read_csv('./data/p_data_wo_content.csv')
# Out:
# /var/folders/52/5ygfc9d94sscvjzdx8yvt2sm0000gq/T/ipykernel_84209/1337043991.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data3 = pd.read_csv('./data/p_data_wo_content.csv')

# %%
data3.describe(include='all')
# Out:
#           Unnamed: 0  item_title    stock_code item_author article_author
# count   6.603696e+06     6603696  6.603696e+06     6603696        3350369  \
# unique           NaN     6405069           NaN        5159           5798
# top              NaN  百联股份今日热门盘点           NaN        股市胖虎            财智星
# freq             NaN         116           NaN      426876        3039821
# mean    3.301848e+06         NaN  3.414867e+05         NaN            NaN
# std     1.906323e+06         NaN  2.724346e+05         NaN            NaN
# min     0.000000e+00         NaN  1.000000e+00         NaN            NaN
# 25%     1.650924e+06         NaN  2.522000e+03         NaN            NaN
# 50%     3.301848e+06         NaN  3.008900e+05         NaN            NaN
# 75%     4.952771e+06         NaN  6.010000e+05         NaN            NaN
# max     6.603695e+06         NaN  6.889810e+05         NaN            NaN
#
#        article_source  eastmoney_robo_journalism  media_robo_journalism
# count         5569905               6.603696e+06           6.603696e+06  \
# unique           2044                        NaN                    NaN
# top      东方财富Choice数据                        NaN                    NaN
# freq          4179997                        NaN                    NaN
# mean              NaN               5.504324e-01           1.353547e-01
# std               NaN               4.974501e-01           3.421020e-01
# min               NaN               0.000000e+00           0.000000e+00
# 25%               NaN               0.000000e+00           0.000000e+00
# 50%               NaN               1.000000e+00           0.000000e+00
# 75%               NaN               1.000000e+00           0.000000e+00
# max               NaN               1.000000e+00           1.000000e+00
#
#         SMA_robo_journalism          year         month         viral
# count          6.603696e+06  6.603696e+06  6.603696e+06  6.603696e+06
# unique                  NaN           NaN           NaN           NaN
# top                     NaN           NaN           NaN           NaN
# freq                    NaN           NaN           NaN           NaN
# mean           2.612287e-01  2.021472e+03  6.593989e+00  4.778476e-02
# std            4.393043e-01  1.164505e+00  3.552674e+00  2.133105e-01
# min            0.000000e+00  2.017000e+03  1.000000e+00  0.000000e+00
# 25%            0.000000e+00  2.021000e+03  4.000000e+00  0.000000e+00
# 50%            0.000000e+00  2.022000e+03  7.000000e+00  0.000000e+00
# 75%            1.000000e+00  2.022000e+03  1.000000e+01  0.000000e+00
# max            1.000000e+00  2.023000e+03  1.200000e+01  1.000000e+00

# %%
data2['stock_code'] = data3['stock_code']

# %%
data2.describe(include='all')

# %%
data2.to_csv('./data/eastmoney_topic_bert.csv')

# %%
import pandas as pd

# %%
data = pd.read_csv('./data/eastmoney_topic_bert.csv')
# Out:
# /var/folders/52/5ygfc9d94sscvjzdx8yvt2sm0000gq/T/ipykernel_88422/2192251410.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./data/eastmoney_topic_bert.csv')

# %%
# Convert strings to lists
data['topics_val'] = data['topics_val'].apply(lambda x: list(map(float, x.strip('[]').split(','))))

# Create separate columns for each value
data[['topics_val1', 'topics_val2', 'topics_val3', 'topics_val4', 'topics_val5', 'topics_val6', 'topics_val7', 'topics_val8']] = pd.DataFrame(data['topics_val'].tolist())

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'item_title', 'item_author', 'article_author',
#        'article_source', 'item_views', 'item_comment_counts', 'article_likes',
#        'year', 'month', 'eastmoney_robo_journalism', 'media_robo_journalism',
#        'SMA_robo_journalism', 'viral', 'article_source_cate',
#        'item_author_cate', 'sentiment_score', 'cut_titles', 'topics',
#        'dominant_topic', 'topics_val', 'stock_code', 'topics_val1',
#        'topics_val2', 'topics_val3', 'topics_val4', 'topics_val5',
#        'topics_val6', 'topics_val7', 'topics_val8'],
#       dtype='object')

# %%
data['topics_val1']
# Out:
# 0          0.013899
# 1          0.013894
# 2          0.236181
# 3          0.240432
# 4          0.236203
#              ...
# 6603691    0.010427
# 6603692    0.011381
# 6603693    0.086750
# 6603694    0.010429
# 6603695    0.017900
# Name: topics_val1, Length: 6603696, dtype: float64

# %%
data.fillna(0, inplace=True)

# %%
data[['dominant_topic','topics_val','topics_val', 'stock_code', 'topics_val1',
       'topics_val2', 'topics_val3', 'topics_val4', 'topics_val5',
       'topics_val6', 'topics_val7', 'topics_val8']]
# Out:
#          dominant_topic                                         topics_val
# 0                     4  [0.01389906, 0.01396003, 0.1250848, 0.01389934...  \
# 1                     4  [0.01389387, 0.01399399, 0.1250381, 0.01389387...
# 2                     0  [0.236181, 0.2328616, 0.2075994, 0.01389296, 0...
# 3                     1      [0.2404324, 0.4798751, 0.1547088, 0.08651243]
# 4                     0  [0.2362029, 0.2337483, 0.207625, 0.01389421, 0...
# ...                 ...                                                ...
# 6603691               4  [0.01042749, 0.0963754, 0.093776, 0.1346095, 0...
# 6603692               4  [0.01138086, 0.2002967, 0.01137208, 0.01138353...
# 6603693               4                   [0.08675, 0.3957798, 0.46922246]
# 6603694               4  [0.0104294, 0.010424, 0.01042315, 0.01043337, ...
# 6603695               3  [0.01790007, 0.0179, 0.01790007, 0.8746995, 0....
#
#                                                 topics_val  stock_code
# 0        [0.01389906, 0.01396003, 0.1250848, 0.01389934...           1  \
# 1        [0.01389387, 0.01399399, 0.1250381, 0.01389387...           1
# 2        [0.236181, 0.2328616, 0.2075994, 0.01389296, 0...           1
# 3            [0.2404324, 0.4798751, 0.1547088, 0.08651243]           1
# 4        [0.2362029, 0.2337483, 0.207625, 0.01389421, 0...           1
# ...                                                    ...         ...
# 6603691  [0.01042749, 0.0963754, 0.093776, 0.1346095, 0...      688981
# 6603692  [0.01138086, 0.2002967, 0.01137208, 0.01138353...      688981
# 6603693                   [0.08675, 0.3957798, 0.46922246]      688981
# 6603694  [0.0104294, 0.010424, 0.01042315, 0.01043337, ...      688981
# 6603695  [0.01790007, 0.0179, 0.01790007, 0.8746995, 0....      688981
#
#          topics_val1  topics_val2  topics_val3  topics_val4  topics_val5
# 0           0.013899     0.013960     0.125085     0.013899     0.652345  \
# 1           0.013894     0.013994     0.125038     0.013894     0.657507
# 2           0.236181     0.232862     0.207599     0.013893     0.013895
# 3           0.240432     0.479875     0.154709     0.086512     0.000000
# 4           0.236203     0.233748     0.207625     0.013894     0.013894
# ...              ...          ...          ...          ...          ...
# 6603691     0.010427     0.096375     0.093776     0.134609     0.633542
# 6603692     0.011381     0.200297     0.011372     0.011384     0.731438
# 6603693     0.086750     0.395780     0.469222     0.000000     0.000000
# 6603694     0.010429     0.010424     0.010423     0.010433     0.835409
# 6603695     0.017900     0.017900     0.017900     0.874699     0.017900
#
#          topics_val6  topics_val7  topics_val8
# 0           0.013910     0.013899     0.153002
# 1           0.013894     0.013894     0.147885
# 2           0.013894     0.153427     0.128248
# 3           0.000000     0.000000     0.000000
# 4           0.013894     0.153434     0.127307
# ...              ...          ...          ...
# 6603691     0.010421     0.010421     0.010427
# 6603692     0.011376     0.011372     0.011380
# 6603693     0.000000     0.000000     0.000000
# 6603694     0.010433     0.010423     0.102024
# 6603695     0.017900     0.017900     0.017900
#
# [6603696 rows x 12 columns]

# %% [markdown]
# # BPR Dataset

# %%
import pandas as pd
from tqdm import tqdm

# %%
data = pd.read_csv('./data/eastmoney_topic_bert.csv')
# Out:
# /var/folders/yp/6t4g6k6570n9w0267tqrkb4m0000gn/T/ipykernel_63693/2192251410.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./data/eastmoney_topic_bert.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'item_title', 'item_author',
#        'article_author', 'article_source', 'item_views', 'item_comment_counts',
#        'article_likes', 'year', 'month', 'eastmoney_robo_journalism',
#        'media_robo_journalism', 'SMA_robo_journalism', 'viral',
#        'article_source_cate', 'item_author_cate', 'sentiment_score',
#        'cut_titles', 'topics', 'dominant_topic', 'topics_val', 'stock_code',
#        'topics_val1', 'topics_val2', 'topics_val3', 'topics_val4',
#        'topics_val5', 'topics_val6', 'topics_val7', 'topics_val8'],
#       dtype='object')

# %%
columns_to_exclude = ['Unnamed: 0.1', 'Unnamed: 0','cut_titles','topics','dominant_topic','topics_val']  # Add the names of the columns you want to exclude

# Drop the specified columns from the DataFrame
data = data.drop(columns=columns_to_exclude)

# %%
cat_cols = ['stock_code',
            'month', 
            'year', 
            'eastmoney_robo_journalism', 
            'media_robo_journalism', 
            'SMA_robo_journalism']
data[cat_cols] =data[cat_cols].apply(lambda c: c.astype('category'))
for cat_col in cat_cols:
    data[f'{cat_col}_index'] = data[cat_col].cat.codes+1 #+1 for nan cases

# %%
user_cols = ['item_author_cate', 
            'article_author', 
            'article_source_cate']
data[user_cols] = data[user_cols].apply(lambda c: c.astype('category'))
for user_col in user_cols:
    data[f'{user_col}_index'] = data[user_col].cat.codes+1 #+1 for nan cases

# %%
positive_rows = data[data['viral'] == 1]

neg_samples = 100
null_count = 0

# Output file path
output_path = './data/eastmoney_bpr.csv'

# Open the output file
with open(output_path, 'w') as f:
    first_line = True

    # Iterate over each positive row
    for index, positive_row in tqdm(positive_rows.iterrows(), total=positive_rows.shape[0]):
        # Find corresponding negative row based on specified conditions
        negative_rows = data[(data['item_author_cate'] == positive_row['item_author_cate']) &
                            (data['article_author'] == positive_row['article_author']) &
                            (data['article_source_cate'] == positive_row['article_source_cate']) &
                            (data['viral'] == 0)]
        
        # Check if there are valid negative rows
        if len(negative_rows)==0:
            negative_rows = data[(data['stock_code'] == positive_row['stock_code']) &
                                (data['viral'] == 0)]
            
        if len(negative_rows)==0:
            null_count+=1

        elif len(negative_rows)==1:
            concatenated_row = pd.concat([positive_row, negative_rows.add_prefix('neg_')])
            f.write('\\'.join(map(str, concatenated_row.values)) + '\n')
            continue

        elif 1<len(negative_rows)<=neg_samples:
            # Take the first negative row
            negative_row = negative_rows
         
        elif len(negative_rows)>neg_samples:
            # Take the first negative row
            negative_row = negative_rows.sample(n=neg_samples, replace=False)
        
        # Iterate over each sampled negative row
        for _, negative_row in negative_row.iterrows():
            # Concatenate negative row to positive row with modifications
            concatenated_row = pd.concat([positive_row, negative_row.add_prefix('neg_')])

            if first_line:
                f.write('\\'.join(map(str, concatenated_row.keys()))+'\n')
                first_line = False

            # Write the concatenated row to the file
            f.write('\\'.join(map(str, concatenated_row.values)) + '\n')
        
# with open(output_path, 'r') as file:
#     existing_content = file.read()
# src=open(output_path,"w") 
# src.write(','.join(map(str, concatenated_row.keys()))+'\n' + existing_content) 
# src.close()
# Out:
#  10%|▉         | 31379/315556 [53:45<8:06:52,  9.73it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/yp/6t4g6k6570n9w0267tqrkb4m0000gn/T/ipykernel_63693/3323001059.py in ?()
#      39             # Take the first negative row
#      40             negative_row = negative_rows.sample(n=neg_samples, replace=False)
#      41
#      42         # Iterate over each sampled negative row
# ---> 43         for _, negative_row in negative_row.iterrows():
#      44             # Concatenate negative row to positive row with modifications
#      45             concatenated_row = pd.concat([positive_row, negative_row.add_prefix('neg_')])
#      46
#
# ~/.local/share/virtualenvs/MTL_project-JGS0j4It/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
test_read = pd.read_csv('./data/eastmoney_bpr.csv',sep='\\')

# %%
test_read.describe(include='all')
# Out:
#              item_title   item_author  article_author article_source
# count             27368         27368         27368.0          27368  \
# unique              409            27             NaN            152
# top     泛海控股股价创逾195个月新低  股友H53p867689             NaN              0
# freq                300          6538             NaN          18510
# mean                NaN           NaN             0.0            NaN
# std                 NaN           NaN             0.0            NaN
# min                 NaN           NaN             0.0            NaN
# 25%                 NaN           NaN             0.0            NaN
# 50%                 NaN           NaN             0.0            NaN
# 75%                 NaN           NaN             0.0            NaN
# max                 NaN           NaN             0.0            NaN
#
#            item_views  item_comment_counts  article_likes          year
# count    27368.000000         27368.000000   27368.000000  27368.000000  \
# unique            NaN                  NaN            NaN           NaN
# top               NaN                  NaN            NaN           NaN
# freq              NaN                  NaN            NaN           NaN
# mean     10268.795126             6.392502       9.160370   2021.064674
# std      16290.769615            13.237972       8.760282      0.694384
# min       5017.000000             0.000000       0.000000   2020.000000
# 25%       5767.000000             1.000000       2.000000   2021.000000
# 50%       6905.000000             3.000000       7.000000   2021.000000
# 75%      10632.000000             8.000000      14.000000   2021.000000
# max     258000.000000           216.000000      76.000000   2023.000000
#
#                month  eastmoney_robo_journalism  ...  neg_topics_val8
# count   27368.000000                    27368.0  ...     27368.000000  \
# unique           NaN                        NaN  ...              NaN
# top              NaN                        NaN  ...              NaN
# freq             NaN                        NaN  ...              NaN
# mean        6.427360                        0.0  ...         0.161624
# std         2.891742                        0.0  ...         0.200848
# min         1.000000                        0.0  ...         0.000000
# 25%         4.000000                        0.0  ...         0.010433
# 50%         5.000000                        0.0  ...         0.092885
# 75%         9.000000                        0.0  ...         0.268681
# max        12.000000                        0.0  ...         0.927058
#
#         neg_stock_code_index  neg_month_index neg_year_index
# count           27368.000000     27368.000000   27368.000000  \
# unique                   NaN              NaN            NaN
# top                      NaN              NaN            NaN
# freq                     NaN              NaN            NaN
# mean               67.592224         6.539572       3.241084
# std                39.229383         2.905530       0.743968
# min                 1.000000         1.000000       1.000000
# 25%                33.000000         4.000000       3.000000
# 50%                67.000000         7.000000       3.000000
# 75%                98.000000         9.000000       4.000000
# max               146.000000        12.000000       5.000000
#
#        neg_eastmoney_robo_journalism_index  neg_media_robo_journalism_index
# count                              27368.0                          27368.0  \
# unique                                 NaN                              NaN
# top                                    NaN                              NaN
# freq                                   NaN                              NaN
# mean                                   1.0                              1.0
# std                                    0.0                              0.0
# min                                    1.0                              1.0
# 25%                                    1.0                              1.0
# 50%                                    1.0                              1.0
# 75%                                    1.0                              1.0
# max                                    1.0                              1.0
#
#         neg_SMA_robo_journalism_index  neg_item_author_cate_index
# count                         27368.0                27368.000000  \
# unique                            NaN                         NaN
# top                               NaN                         NaN
# freq                              NaN                         NaN
# mean                              1.0                   23.027770
# std                               0.0                   11.918474
# min                               1.0                    1.000000
# 25%                               1.0                   13.000000
# 50%                               1.0                   29.000000
# 75%                               1.0                   32.000000
# max                               1.0                   43.000000
#
#         neg_article_author_index  neg_article_source_cate_index
# count               27368.000000                   27368.000000
# unique                       NaN                            NaN
# top                          NaN                            NaN
# freq                         NaN                            NaN
# mean                    1.561130                       1.785479
# std                     0.496258                       1.183058
# min                     1.000000                       1.000000
# 25%                     1.000000                       1.000000
# 50%                     2.000000                       1.000000
# 75%                     2.000000                       3.000000
# max                     2.000000                       7.000000
#
# [11 rows x 68 columns]

# %%
import pandas as pd

# %%
with open("./data/eastmoney_bpr_train.csv", 'r') as f:
    for i in range(100):
        # if i == 67:
        print(f.readline())
# Out:
# item_title*item_author*article_author*article_source*item_views*item_comment_counts*article_likes*year*month*eastmoney_robo_journalism*media_robo_journalism*SMA_robo_journalism*viral*article_source_cate*item_author_cate*sentiment_score*stock_code*topics_val1*topics_val2*topics_val3*topics_val4*topics_val5*topics_val6*topics_val7*topics_val8*stock_code_index*month_index*year_index*eastmoney_robo_journalism_index*media_robo_journalism_index*SMA_robo_journalism_index*item_author_cate_index*article_author_index*article_source_cate_index*neg_item_title*neg_item_author*neg_article_author*neg_article_source*neg_item_views*neg_item_comment_counts*neg_article_likes*neg_year*neg_month*neg_eastmoney_robo_journalism*neg_media_robo_journalism*neg_SMA_robo_journalism*neg_viral*neg_article_source_cate*neg_item_author_cate*neg_sentiment_score*neg_stock_code*neg_topics_val1*neg_topics_val2*neg_topics_val3*neg_topics_val4*neg_topics_val5*neg_topics_val6*neg_topics_val7*neg_topics_val8*neg_stock_code_index*neg_month_index*neg_year_index*neg_eastmoney_robo_journalism_index*neg_media_robo_journalism_index*neg_SMA_robo_journalism_index*neg_item_author_cate_index*neg_article_author_index*neg_article_source_cate_index
#
# %%
data = pd.read_csv('./data/eastmoney_bpr_train.csv', delimiter='*',nrows=10)

# %%
import pandas as pd

# %%
data = pd.read_csv("./data/eastmoney_topic_bert.csv")
# Out:
# /var/folders/yp/6t4g6k6570n9w0267tqrkb4m0000gn/T/ipykernel_796/2566476577.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("./data/eastmoney_topic_bert.csv")

# %%
data['item_author'].unique()
# Out:
# array(['股友L0L2595133', '一句话财报', '股市胖虎', ..., '退市锐电资讯',
#        'DIVERSIFIED ENER资讯', '征宙机械资讯'], dtype=object)

# %%
data[['Unnamed: 0.1', 'Unnamed: 0']]
# Out:
#          Unnamed: 0.1  Unnamed: 0
# 0                   0           0
# 1                   1           1
# 2                   2           2
# 3                   3           3
# 4                   4           4
# ...               ...         ...
# 6603691       6603691     6603691
# 6603692       6603692     6603692
# 6603693       6603693     6603693
# 6603694       6603694     6603694
# 6603695       6603695     6603695
#
# [6603696 rows x 2 columns]

# %%
columns_to_exclude = ['Unnamed: 0.1', 'Unnamed: 0']  # Add the names of the columns you want to exclude
data = data.drop(columns=columns_to_exclude)

# %%
data.columns
# Out:
# Index(['item_title', 'item_author', 'article_author', 'article_source',
#        'item_views', 'item_comment_counts', 'article_likes', 'year', 'month',
#        'eastmoney_robo_journalism', 'media_robo_journalism',
#        'SMA_robo_journalism', 'viral', 'article_source_cate',
#        'item_author_cate', 'sentiment_score', 'cut_titles', 'topics',
#        'dominant_topic', 'topics_val', 'stock_code', 'topics_val1',
#        'topics_val2', 'topics_val3', 'topics_val4', 'topics_val5',
#        'topics_val6', 'topics_val7', 'topics_val8'],
#       dtype='object')

# %%
data.to_csv("eastmoney_bert.csv", index=False)

# %%
data = pd.read_csv("./data/eastmoney_bert.csv")
data.columns
# Out:
# /var/folders/yp/6t4g6k6570n9w0267tqrkb4m0000gn/T/ipykernel_796/2619987834.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("./data/eastmoney_bert.csv")
# Index(['item_title', 'item_author', 'article_author', 'article_source',
#        'item_views', 'item_comment_counts', 'article_likes', 'year', 'month',
#        'eastmoney_robo_journalism', 'media_robo_journalism',
#        'SMA_robo_journalism', 'viral', 'article_source_cate',
#        'item_author_cate', 'sentiment_score', 'cut_titles', 'topics',
#        'dominant_topic', 'topics_val', 'stock_code', 'topics_val1',
#        'topics_val2', 'topics_val3', 'topics_val4', 'topics_val5',
#        'topics_val6', 'topics_val7', 'topics_val8'],
#       dtype='object')

# %% [markdown]
# # fuse industry & sector info

# %% [markdown]
# First, I suggest we not use stock_code as features because there are too many stocks, making the model difficult to train and generalize to new stocks.
# Instead, I suggest we use industries. Please see attached for industries matched to our data (about 36 stocks in our sample are not matched). IndustryCode1 has 19 categories (sectors), and IndustryCode2 has 81 categories (industries). Note that each stock might correspond to multiple industries. This industry classification is from CSRC证监会. I have also collected other industry standards like 申银万国2014, 中信证券行业 and 中证2016, but there are about 1000 unmatched stocks, so I did not provide the data for now.
#
# Second, I suggest we not use item_author, article_source and article_author directly, either. This is because I feel that using these variables directly reduces interpretability of model results and generalizability to new sources/authors. The three variables I created, easymoney_robo_journalism, media_robo_journalism and SMA_robo_journalism capture some information about sources (Easymoney vs. media vs. SMA) and authors (robot vs. human).
# If the model team feel necessary to include more information about sources and authors, I suggest we reduce the categories of sources or authors to 10-20, by using top 10/20 + an artificial category called OTHER.

# %%
import pandas as pd
import pyreadr

# %%
ind_data = pyreadr.read_r('./data/industry_csrc2012_matched.RData')
# print(data.keys())
ind_data = ind_data["industry_csrc2012_matched"]

# %%
ind_data.columns
# Out:
# Index(['stock_code', 'IndustryCode1', 'IndustryName1', 'IndustryCode2',
#        'IndustryName2'],
#       dtype='object')

# %%
ind_data.describe(include='all')
# Out:
#        stock_code IndustryCode1 IndustryName1 IndustryCode2     IndustryName2
# count        5410          5410          5410          5410              5410
# unique       5016            19            19            81                81
# top        002266             C           制造业           C39  计算机、通信和其他电子设备制造业
# freq            3          3506          3506           586               586

# %%
ind_data['stock_code'] = ind_data['stock_code'].astype(int)

# %%
ind_data
# Out:
#       stock_code IndustryCode1    IndustryName1 IndustryCode2  \
# 0              1             J              金融业           J66
# 1              2             K             房地产业           K70
# 2              4             C              制造业           C27
# 3              4             I  信息传输、软件和信息技术服务业           I65
# 4              5             N    水利、环境和公共设施管理业           N77
# ...          ...           ...              ...           ...
# 5405      600270             G      交通运输、仓储和邮政业           G58
# 5406      600401             C              制造业           C39
# 5407      600432             C              制造业           C32
# 5408      600747             F           批发和零售业           F51
# 5409      600806             C              制造业           C34
#
#          IndustryName2
# 0               货币金融服务
# 1                 房地产业
# 2                医药制造业
# 3           软件和信息技术服务业
# 4           生态保护和环境治理业
# ...                ...
# 5405        装卸搬运和运输代理业
# 5406  计算机、通信和其他电子设备制造业
# 5407      有色金属冶炼及压延加工业
# 5408               批发业
# 5409           通用设备制造业
#
# [5410 rows x 5 columns]

# %%
raw_data = pd.read_csv("./data/eastmoney_bert.csv")

# %%
raw_data.columns
# Out:
# Index(['item_title', 'item_author_cate', 'article_author',
#        'article_source_cate', 'month', 'eastmoney_robo_journalism',
#        'media_robo_journalism', 'SMA_robo_journalism', 'viral',
#        'sentiment_score', 'topics_val1', 'topics_val2', 'topics_val3',
#        'topics_val4', 'topics_val5', 'stock_code'],
#       dtype='object')

# %%
raw_data['stock_code'].dtype
# Out:
# dtype('int64')

# %%
merged_data = raw_data.merge(ind_data, on='stock_code', how='left')

# %%
# check merge result: 36 stocks not matched
merged_data[merged_data['IndustryCode1'].isnull()]['stock_code'].nunique()
# Out:
# 36

# %%
print(f"rows b4 merging: {len(merged_data)}")
merged_data = merged_data.dropna()
print(f"rows after merging: {len(merged_data)}")
# Out:
# rows b4 merging: 7152042
# rows after merging: 7138784

# %%
merged_data.to_csv('./data/eastmoney_bert_ind.csv', index=False)
